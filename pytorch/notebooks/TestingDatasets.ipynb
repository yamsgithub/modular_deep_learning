# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm  # colormaps 
                                        
# %matplotlib inline

# %%
import numpy as np

# %%
import seaborn as sns

# %%
transl = - 3
X = np.random.normal(size=(3000, 2))
X[0:600, ] = X[0:600,:] + transl
X[601:1200, ] = X[601:1200,:] - transl
y = np.zeros((3000))
y[0:1200] = 1
print(y.shape)
fig,ax = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(20,15))
sns.scatterplot(x=X[:,0],y=X[:,1], ax=ax,
               hue=y,palette=['r','c'])
# Out:
# (3000,)
# <AxesSubplot:>

# %%
from sklearn import datasets, mixture
from sklearn.preprocessing import StandardScaler

np.random.seed(0)

n_samples = 3000
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5,
                                      noise=.11)

# Anisotropicly distributed data
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)

plt.figure(figsize=(10, 5))

X, y = noisy_circles

# normalize dataset for easier parameter selection
X = StandardScaler().fit_transform(X)

plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[y])
plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
im = plt.imread('figures/data.png')
plt.imshow(im)

# %%
im.shape
# Out:
# (200, 141, 4)

# %%
X1 = np.where(im[:,:,0] > 0)[0]
Y1 = np.where(im[:,:,0] > 0)[1]
labels1 = np.ones(X1.shape).astype(int)
X2 = np.where(im[:,:,2] > 0)[0]
Y2 = np.where(im[:,:,2] > 0)[1]
labels2 = np.zeros(X2.shape).astype(int)
X = np.asarray([list(X1)+list(X2), list(Y1)+list(Y2)]).transpose().astype('float32')
y = list(labels1) + list(labels2)

original_X = X
original_y = y
for i in range(0,5):
    noise = np.random.normal(0, 3.0, original_X.shape)
#     print('noise',noise)
    X1 = np.add(original_X, noise)
    X = np.vstack((X,X1))
    y = y + original_y    
print(X.shape, len(y))
# Out:
# (6834, 2) 6834

# %%
thefigsize = (20*2,15*2)
fig,ax = plt.subplots(2, 1, sharex=True, sharey=True, figsize=thefigsize)
print(X.shape, len(y))
sns.scatterplot(x=original_X[:,0],y=original_X[:,1],hue=original_y,palette=['r','c'], ax=ax[0])
sns.scatterplot(x=X[:,0],y=X[:,1],hue=y,palette=['r','c'], ax=ax[1])
plt.show()
# sns.scatterplot(x=X1[:,0],y=X1[:,1],hue=labels,palette=['r','c'], ax=ax)
# plt.savefig('figures/all/custom_data.png')
# Out:
# (6834, 2) 6834
